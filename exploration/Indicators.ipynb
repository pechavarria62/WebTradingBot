# %%
import sys
sys.path.append('../')
from plotting import CandlePlot
import pandas as pd

# %%
from technicals.indicators import BollingerBands, ATR, KeltnerChannels, RSI, MACD

# %%
df = pd.read_pickle("../data/AUD_CAD_H1.pkl")

# %%
df_an = df.copy()

# %%
df_an = MACD(df_an)

# %%
df_an.tail()
# Out:
#                            time  volume    mid_o    mid_h    mid_l    mid_c  \
# 37255 2024-12-30 19:00:00+00:00    1288  0.89410  0.89420  0.89358  0.89358
# 37256 2024-12-30 20:00:00+00:00     927  0.89362  0.89418  0.89286  0.89306
# 37257 2024-12-30 21:00:00+00:00     551  0.89312  0.89316  0.89256  0.89311
# 37258 2024-12-30 22:00:00+00:00     875  0.89298  0.89386  0.89233  0.89239
# 37259 2024-12-30 23:00:00+00:00     562  0.89230  0.89256  0.89190  0.89230
#
#          bid_o    bid_h    bid_l    bid_c    ask_o    ask_h    ask_l    ask_c  \
# 37255  0.89397  0.89407  0.89344  0.89344  0.89423  0.89433  0.89371  0.89373
# 37256  0.89348  0.89407  0.89271  0.89293  0.89377  0.89431  0.89300  0.89319
# 37257  0.89299  0.89302  0.89241  0.89275  0.89325  0.89364  0.89270  0.89347
# 37258  0.89266  0.89312  0.89116  0.89177  0.89330  0.89505  0.89288  0.89301
# 37259  0.89168  0.89241  0.89139  0.89215  0.89292  0.89302  0.89219  0.89244
#
#            MACD    SIGNAL      HIST
# 37255 -0.000664 -0.000229 -0.000435
# 37256 -0.000782 -0.000339 -0.000443
# 37257 -0.000862 -0.000444 -0.000419
# 37258 -0.000973 -0.000550 -0.000423
# 37259 -0.001055 -0.000651 -0.000405

# %%
dfp = df_an.iloc[-100:]
cp = CandlePlot(dfp, candles=True)
cp.show_plot(line_traces=[], sec_traces=[])

# %%
import plotly.graph_objects as go

# %%
cp = CandlePlot(dfp, candles=False)
cp.fig.add_trace(go.Bar(
    x=cp.df_plot.sTime,
    y=cp.df_plot.HIST,
    name="HIST"
))
cp.show_plot(line_traces=['SIGNAL', 'MACD'], sec_traces=[])
